# %%
print("Is your number odd or even? Let's find out!")
Number = int(input("Please enter a number:"))
if Number % 2 == 0:
    print("Your number is even!")
else:
    print("Your number is odd!")
# Out:
# Is your number odd or even? Let's find out!
# Please enter a number: 6
# Your number is even!

# %%
print("Is your number odd or even? Let's find out!")
response = "yes"

while response == "yes":
    Number = int(input("\nPlease enter a number (integers only):"))
    if Number % 8 == 0:
        print("\nYour number is even and is also a multiple of 8, 4, and 2! \nThink of 8 like a lazy infinity sign, Nap Time Now! :D ") 
    elif Number % 4 == 0:
        print("\nYour number is even and is also a multiple of 4 and 2! \nDid you know 4 is the only English number that has the same numbers of letters as its value! :o ")
    elif Number % 2 == 0:
        print("\nYour number is even! \nThat means the shared amount for you will be the same amount for me! :P")

        
    else:
        print("\nYour number is odd!\nDid you know the odds of your number being odd, was actually even! :)")
        
    response = input("\nWould you like to check another number? (yes or no):").lower()
    
    while response != "yes" and response != "no":
        print ( "\nError: only 'yes' or 'no' responses are accepted. Please try again!")
        response = input("\nWould you like to check another number? (yes or no):")
    if response == "yes":
        print ("\nLet's check another number!")
    elif response == "no":
        print( "\nThank you for using the program!")
# Out:
# Is your number odd or even? Let's find out!
# Please enter a number (integers only): 8
# Your number is even and is also a multiple of 8, 4, and 2!
# Think of 8 like a lazy infinity sign, Nap Time Now! :D
# Would you like to check another number? (yes or no): yes
# Let's check another number!
# Please enter a number (integers only): 4
# Your number is even and is also a multiple of 4 and 2!
# Did you know 4 is the only English number that has the same numbers of letters as its value! :o
# Would you like to check another number? (yes or no): yes
# Let's check another number!
# Please enter a number (integers only): 2
# Your number is even!
# That means the shared amount for you will be the same amount for me! :P
# Would you like to check another number? (yes or no): 1
# Error: only 'yes' or 'no' responses are accepted. Please try again!
# Would you like to check another number? (yes or no): yes
# Let's check another number!
# Please enter a number (integers only): 1
# ...
